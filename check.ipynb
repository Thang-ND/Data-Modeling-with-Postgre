# %%
# %load_ext sql

# %%
    # %sql postgresql://postgres:test123@127.0.0.1/sparkifydb
# Out:
# 'Connected: postgres@sparkifydb'

# %%
# %sql SELECT * FROM artists
# Out:
#  * postgresql://postgres:***@127.0.0.1/sparkifydb
# 1 rows affected.
# [('ARD0S291187B9B7BF5', 'Rated R', 'Ohio', None, None)]

# %%
# %sql SELECT * FROM songs
# Out:
#  * postgresql://postgres:***@127.0.0.1/sparkifydb
# 1 rows affected.
# [('1', 'Keepin It Real (Skit)', 'ARD0S291187B9B7BF5', 0, 114.78159)]

# %%
# %sql SELECT * FROM time
# Out:
#  * postgresql://postgres:***@127.0.0.1/sparkifydb
# 171 rows affected.
# [(datetime.datetime(2018, 11, 2, 1, 25, 34, 796000), 1, 2, 44, 11, 2018, 'Friday'),
#  (datetime.datetime(2018, 11, 2, 1, 29, 36, 796000), 1, 2, 44, 11, 2018, 'Friday'),
#  (datetime.datetime(2018, 11, 2, 1, 30, 41, 796000), 1, 2, 44, 11, 2018, 'Friday'),
#  (datetime.datetime(2018, 11, 2, 1, 34, 17, 796000), 1, 2, 44, 11, 2018, 'Friday'),
#  (datetime.datetime(2018, 11, 2, 2, 42, 48, 796000), 2, 2, 44, 11, 2018, 'Friday'),
#  (datetime.datetime(2018, 11, 2, 3, 5, 57, 796000), 3, 2, 44, 11, 2018, 'Friday'),
#  (datetime.datetime(2018, 11, 2, 3, 32, 41, 796000), 3, 2, 44, 11, 2018, 'Friday'),
#  (datetime.datetime(2018, 11, 2, 3, 34, 34, 796000), 3, 2, 44, 11, 2018, 'Friday'),
#  (datetime.datetime(2018, 11, 2, 5, 15, 41, 796000), 5, 2, 44, 11, 2018, 'Friday'),
#  (datetime.datetime(2018, 11, 2, 5, 52, 29, 796000), 5, 2, 44, 11, 2018, 'Friday'),
# ...

# %%
# %sql SELECT * FROM users
# Out:
#  * postgresql://postgres:***@127.0.0.1/sparkifydb
# 22 rows affected.
# [(101, 'Jayden', 'Fox', 'M', 'free'),
#  (83, 'Stefany', 'White', 'F', 'free'),
#  (48, 'Marina', 'Sutton', 'F', 'free'),
#  (17, 'Makinley', 'Jones', 'F', 'free'),
#  (66, 'Kevin', 'Arellano', 'M', 'free'),
#  (89, 'Kynnedi', 'Sanchez', 'F', 'free'),
#  (88, 'Mohammad', 'Rodriguez', 'M', 'free'),
#  (75, 'Joseph', 'Gutierrez', 'M', 'free'),
#  (12, 'Austin', 'Rosales', 'M', 'free'),
#  (10, 'Sylvie', 'Cruz', 'F', 'free'),
#  (50, 'Ava', 'Robinson', 'F', 'free'),
#  (71, 'Ayleen', 'Wise', 'F', 'free'),
#  (54, 'Kaleb', 'Cook', 'M', 'free'),
#  (3, 'Isaac', 'Valdez', 'M', 'free'),
#  (49, 'Chloe', 'Cuevas', 'F', 'free'),
#  (44, 'Aleena', 'Kirby', 'F', 'paid'),
#  (100, 'Adler', 'Barrera', 'M', 'free'),
#  (15, 'Lily', 'Koch', 'F', 'paid'),
#  (80, 'Tegan', 'Levine', 'F', 'free'),
#  (26, 'Ryan', 'Smith', 'M', 'free'),
#  (61, 'Samuel', 'Gonzalez', 'M', 'free'),
#  (86, 'Aiden', 'Hess', 'M', 'free')]
